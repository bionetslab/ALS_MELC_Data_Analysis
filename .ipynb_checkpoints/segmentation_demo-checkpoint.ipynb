# %%
import matplotlib.pyplot as plt
import json
import os
import cv2
import time
import numpy as np
from csbdeep.utils import Path, normalize
from segmentation import MELC_Segmentation
# Out:
# 2023-05-15 17:22:53.062955: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-15 17:22:53.064119: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-15 17:22:53.088888: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-15 17:22:53.089269: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-15 17:22:53.479086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# %load_ext autoreload
# %autoreload 2

# %%
data = "ALS"

f = open('/data_slow/je30bery/spatial_proteomics/config.json')
config = json.load(f)
data_path = config[data]
seg = MELC_Segmentation(data_path, membrane_marker="cd45") 
# membrane_marker: str/None 
# radius: multiple of cell radius

# %%
seg.fields_of_view
# Out:
# ['ALS01 - 21297',
#  'ALS01 - 21298',
#  'ALS01 - 21299',
#  'ALS01 - 21300',
#  'ALS02 - 21301',
#  'ALS02 - 21302',
#  'ALS02 - 21303',
#  'ALS02 - 21304',
#  'ALS03 - 21305',
#  'ALS03 - 21306',
#  'ALS03 - 21307',
#  'ALS03 - 21308',
#  'Healthy01 - 21315',
#  'Healthy01 - 21316',
#  'Healthy01 - 21317',
#  'Healthy01 - 21318',
#  'Healthy02 - 21319',
#  'Healthy02 - 21320',
#  'Healthy02 - 21321',
#  'Healthy02 - 21322',
#  'Healthy03 - 21323',
#  'Healthy03 - 21324',
#  'Healthy03 - 21325',
#  'Healthy03 - 21326',
#  'Healthy04 - 21335',
#  'Healthy04 - 21336',
#  'Healthy04 - 21337',
#  'Healthy04 - 21338',
#  'Healthy05 - 21331',
#  'Healthy05 - 21332',
#  'Healthy05 - 21333',
#  'Healthy05 - 21334']

# %%
f, axs = plt.subplots(len(seg.fields_of_view), 5, figsize=(18, len(seg.fields_of_view) * 5))
axs[0,0].set_title("Segmented Nuclei")
axs[0,1].set_title("Segmented Membranes")
axs[0,2].set_title("Segmented Membranes that Contain Nucleus")
axs[0,3].set_title("Estimated Membranes around Remaining Nuclei")
axs[0,4].set_title("Complete Membrane Reconstruction")


for i, fow in enumerate(seg.fields_of_view[:1]):
    print(fow)
    print("###################", fow, "######################")
    seg.field_of_view = fow
    prop_iodide = seg.get_prop_iodide()
    cd45 = seg.get_membrane_marker()
    #nuclei, membranes = seg.run(seg) # radius: relative to nucleus size 
    nuclei_labels, nuclei_centers = seg.segment(prop_iodide)
    membrane_labels, membrane_centers = seg.segment(cd45)
    
    start = time.time()
    reconstructed_membranes1, nuclei_centers_without_membranes1, radius = seg.existing_membranes_as_nuclei_NN(membrane_labels, nuclei_labels, nuclei_centers)
    print("rec took", time.time()-start)
    print(radius)

    start = time.time()
    estimated_membranes1 = seg.estimate_membranes_as_nuclei_NN_in_radius(nuclei_labels, nuclei_centers_without_membranes1, radius)
    print("est took", time.time()-start)

    axs[i,0].imshow(nuclei_labels)
    axs[i,0].axis('off')

    axs[i,1].imshow(membrane_labels)
    axs[i,1].axis('off')
    
    axs[i,2].imshow(reconstructed_membranes1)
    axs[i,2].axis('off')

    axs[i,3].imshow(estimated_membranes1)
    axs[i,3].axis('off')
        
    axs[i,4].imshow(reconstructed_membranes1 + estimated_membranes1)
    axs[i,4].axis('off')


    #np.save(f"./segmentation_results/{fow}_nuclei.npy", nuclei.astype(int))
    #np.save(f"./segmentation_results/{fow}_membranes.npy", membranes.astype(int))
plt.tight_layout()
plt.show()
# Out:
# ALS01 - 21297
# ################### ALS01 - 21297 ######################
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 806ms/step
# 5891it [00:42, 139.17it/s]
# rec took 42.348984241485596
# 1.09648988884343
# est took 44.16346859931946

# %%
plt.imshow(nuclei_labels == 5385)

# %%
plt.imshow(nuclei_labels)

# %%
nuclei_labels[240, 30]
# Out:
# 5385

# %%
np.sum(nuclei_labels == 5385)
# Out:
# 4164

# %%
plt.imshow(nuclei_labels == 5385)

# %%
print(seg.field_of_view)
# Out:
# ALS01 - 21297

# %%
prop_iodide = seg.get_prop_iodide()
cd45 = seg.get_membrane_marker()

# %%
f, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].axis('off')
axs[0, 0].imshow(prop_iodide)
axs[0, 0].set_title("Propidium Iodide - Bleach Image")
axs[0, 1].axis('off')
axs[0, 1].imshow(cd45)
axs[0, 1].set_title("CD45")
axs[1, 0].axis('off')
axs[1, 0].imshow(prop_iodide[:250, :250])
axs[1, 1].axis('off')
axs[1, 1].imshow(cd45[:250, :250])
plt.show()

# %%
nuclei_labels, nuclei_centers = seg.segment(prop_iodide)
membrane_labels, membrane_centers = seg.segment(cd45)
# Out:
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 765ms/step

# %%
seg.field_of_view = 'ALS01 - 21297'

# %%
def radius_from_max_dist_within_segment(segment):
    x_min = np.min(segment[0])
    x_max = np.max(segment[0])
    x_diff = x_max - x_min
    y_min = np.min(segment[1])
    y_max = np.max(segment[1])
    y_diff = y_max - y_min
    diff = x_diff if x_diff > y_diff else y_diff
    radius = diff / 2
    return radius

from tqdm import tqdm
def in_circle(x, y, x_c, y_c, radius):
    return (x - x_c) ** 2 + (y - y_c) ** 2 <= radius ** 2 
    
from scipy.spatial import KDTree
kdtree = KDTree(nuclei_centers, leafsize=100)

reconstructed_membranes = np.zeros_like(membrane_labels, dtype=int)
nuclei_centers_without_membrane = dict()

nucleus_radii = list()
membrane_radii = list()
nucleus_radii_to_circle = dict()

for idx, point in tqdm(enumerate(nuclei_centers)):
    membrane_label = membrane_labels[int(point[0]), int(point[1])]
    nucleus_label = nuclei_labels[int(point[0]), int(point[1])]

    if membrane_label > 0: # there is an actual label#
        segment = np.array(np.where(membrane_labels == membrane_label)).T
    else: 
        nuclei_centers_without_membrane[idx] = point
        nucleus = np.where(nuclei_labels == nucleus_label)
        nucleus_radii_to_circle[idx] = radius_from_max_dist_within_nucleus(nucleus)
        continue
    dist, idxs = kdtree.query(segment)
    segment = segment[np.where(idxs == idx)].T
    
        
    # check if membrane is bigger than nucleus:
    
    
    if segment.shape[1] < len(nucleus[0]):
        nuclei_centers_without_membrane[idx] = point
        nucleus = np.where(nuclei_labels == nucleus_label)
        nucleus_radii_to_circle[idx] = radius_from_max_dist_within_nucleus(nucleus)
        continue
    membrane_radii.append(radius_from_max_dist_within_nucleus(segment))
    nucleus_radii.append(radius_from_max_dist_within_nucleus(nucleus))
            
    reconstructed_membranes[segment[0], segment[1]] = nucleus_label
                  
ratio = np.array(membrane_radii) / np.array(nucleus_radii)
radii_ratio = np.median(ratio)
print(radii_ratio)

#n_values, n_counts = np.unique(nuclei_labels, return_counts=True)

reconstructed_membranes = np.zeros_like(nuclei_labels, dtype=int)

xaxis = np.linspace(0, nuclei_labels.shape[0] - 1, nuclei_labels.shape[0])
yaxis = np.linspace(0, nuclei_labels.shape[1] - 1, nuclei_labels.shape[1])

for idx in nuclei_centers_without_membrane:
    point = nuclei_centers_without_membrane[idx]
    nucleus_label = nuclei_labels[int(point[0]), int(point[1])]
    if nucleus_label == 5385:
        print(point)

        

    if idx in nucleus_radii_to_circle:
        nucleus_radius = nucleus_radii_to_circle[idx]
    else:
        nucleus_radius = radius_from_max_dist_within_nucleus(np.where(nuclei_labels == nucleus_label))
   
    absolut_radius = radius * nucleus_radius 
    if nucleus_label == 5385:
        print(nucleus_radius, absolut_radius)
    assert nucleus_radius < absolut_radius
    segment = np.array(np.where(in_circle(xaxis[:,None], yaxis[None,:], int(point[0]), int(point[1]), np.ceil(absolut_radius) + 1))).T
    dist, idxs = kdtree.query(segment)
    if nucleus_label == 5385:
        print(segment.shape)
    segment = segment[np.where(idxs == idx)].T
    if nucleus_label == 5385:
        print(segment.shape)

    reconstructed_membranes[segment[0], segment[1]] = nucleus_label
# Out:
# 5891it [00:46, 126.01it/s]
# 1.1578947368421053
# [236  42]
# 37.0 40.57012588720691
# (5525, 2)
# (2, 5525)

# %%
plt.imshow(nuclei_labels)

# %%
radius

# %%
test = cv2.circle(np.zeros_like(nuclei_labels), (42, 236), 23, 1, -1) 
plt.imshow(test)

# %%
np.sqrt(1793)/np.pi

# %%
np.sum(reconstructed_membranes == 5385)

# %%
22.522164124616 ** 2 * np.pi

# %%
f, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].axis('off')
axs[0,0].imshow(nuclei_labels)
axs[0,0].set_title("Propidium Iodide Segmentation")
axs[0,1].axis('off')
axs[0,1].imshow(membrane_labels)
axs[0,1].set_title("CD45 Segmentation")
axs[1,0].axis('off')
axs[1,0].imshow(nuclei_labels[:250, :250])
axs[1,1].axis('off')
axs[1,1].imshow(membrane_labels[:250, :250])
plt.show()

# %%
import time
start = time.time()
reconstructed_membranes1, nuclei_centers_without_membranes1 = seg.existing_membranes_as_nuclei_NN(membrane_labels, nuclei_labels, nuclei_centers)
print("rec took", time.time()-start)

start = time.time()
radius = seg.estimate_radius(nuclei_labels, reconstructed_membranes1)
print("radius took", time.time()-start)

start = time.time()
estimated_membranes1 = seg.estimate_membranes_as_nuclei_NN_in_radius(nuclei_labels, nuclei_centers_without_membranes1, radius)
print("est took", time.time()-start)

# %%
plt.imshow(nuclei_labels==1)

# %%
print(np.sum(nuclei_labels==1))

# %%
plt.plot(ratio)

# %%
np.mean(ratio)

# %%
median_radius

# %%
f, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0,0].axis('off')
axs[0,0].imshow(reconstructed_membranes1)
axs[0,0].set_title("Segmented Membranes from CD45 \n that contain Nucleus Center")
axs[0,1].axis('off')
axs[0,1].imshow(estimated_membranes1)
axs[0,1].set_title("Estimated Membranes around \n Remaining Nuclei Centers")
axs[1,0].axis('off')
axs[1,0].imshow(reconstructed_membranes1[:250, :250])
axs[1,1].axis('off')
axs[1,1].imshow(estimated_membranes1[:250, :250])
plt.show()

# %%
start = time.time()
reconstructed_membranes2, nuclei_centers_without_membranes2 = seg.existing_membranes_as_nuclei_NN2(membrane_labels, nuclei_labels, nuclei_centers)
print("rec took", time.time()-start)

start = time.time()
radius = seg.estimate_radius(nuclei_labels, reconstructed_membranes2)
print("radius took", time.time()-start)

start = time.time()
estimated_membranes2 = seg.estimate_membranes_as_nuclei_NN_in_radius2(nuclei_labels, nuclei_centers_without_membranes2, radius)
print("est took", time.time()-start)

# %%
f, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0,0].axis('off')
axs[0,0].imshow(reconstructed_membranes2)
axs[0,0].set_title("Segmented Membranes from CD45 \n that contain Nucleus Center")
axs[0,1].axis('off')
axs[0,1].imshow(estimated_membranes2)
axs[0,1].set_title("Estimated Membranes around \n Remaining Nuclei Centers")
axs[1,0].axis('off')
axs[1,0].imshow(reconstructed_membranes2[:250, :250])
axs[1,1].axis('off')
axs[1,1].imshow(estimated_membranes2[:250, :250])
plt.show()

# %%
combined_membranes = reconstructed_membranes1 + estimated_membranes1
f, axs = plt.subplots(2, 1, figsize=(10, 10))
axs[0].axis('off')
axs[0].imshow(combined_membranes)
axs[0].set_title("Combined Membranes")

axs[1].imshow(combined_membranes[:250, :250])
axs[1].axis('off')
plt.show()

# %%
only_membranes = combined_membranes != nuclei_labels
f, axs = plt.subplots(2, 1, figsize=(10, 10))
axs[0].axis('off')
axs[0].imshow(only_membranes)
axs[0].set_title("Combined Membranes")

axs[1].imshow(only_membranes[:250, :250])
axs[1].axis('off')
plt.show()
